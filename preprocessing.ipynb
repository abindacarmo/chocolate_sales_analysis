# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

data = pd.read_csv("chocolate_dataset/Chocolate-Sales.csv")

chocolate_data = data.head(100)

chocolate_data.info()
chocolate_data.describe()
chocolate_data.isnull().sum()
choco_clean = (chocolate_data.dropna().drop_duplicates())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   100 non-null    object
#  1   Country        100 non-null    object
#  2   Product        100 non-null    object
#  3   Date           100 non-null    object
#  4   Amount         100 non-null    object
#  5   Boxes Shipped  100 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
choco_clean.head(100).style #fo sai data kompletu husi 0 to'o 99
# Out:
# <style type="text/css">
# </style>
# <table id="T_3bef7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bef7_level0_col0" class="col_heading level0 col0" >Sales Person</th>
#       <th id="T_3bef7_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_3bef7_level0_col2" class="col_heading level0 col2" >Product</th>
#       <th id="T_3bef7_level0_col3" class="col_heading level0 col3" >Date</th>
#       <th id="T_3bef7_level0_col4" class="col_heading level0 col4" >Amount</th>
#       <th id="T_3bef7_level0_col5" class="col_heading level0 col5" >Boxes Shipped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bef7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3bef7_row0_col0" class="data row0 col0" >Jehu Rudeforth</td>
#       <td id="T_3bef7_row0_col1" class="data row0 col1" >UK</td>
#       <td id="T_3bef7_row0_col2" class="data row0 col2" >Mint Chip Choco</td>
#       <td id="T_3bef7_row0_col3" class="data row0 col3" >04-Jan-22</td>
#       <td id="T_3bef7_row0_col4" class="data row0 col4" >$5,320 </td>
#       <td id="T_3bef7_row0_col5" class="data row0 col5" >180</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3bef7_row1_col0" class="data row1 col0" >Van Tuxwell</td>
#       <td id="T_3bef7_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_3bef7_row1_col2" class="data row1 col2" >85% Dark Bars</td>
#       <td id="T_3bef7_row1_col3" class="data row1 col3" >01-Aug-22</td>
#       <td id="T_3bef7_row1_col4" class="data row1 col4" >$7,896 </td>
#       <td id="T_3bef7_row1_col5" class="data row1 col5" >94</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3bef7_row2_col0" class="data row2 col0" >Gigi Bohling</td>
#       <td id="T_3bef7_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_3bef7_row2_col2" class="data row2 col2" >Peanut Butter Cubes</td>
#       <td id="T_3bef7_row2_col3" class="data row2 col3" >07-Jul-22</td>
#       <td id="T_3bef7_row2_col4" class="data row2 col4" >$4,501 </td>
#       <td id="T_3bef7_row2_col5" class="data row2 col5" >91</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3bef7_row3_col0" class="data row3 col0" >Jan Morforth</td>
#       <td id="T_3bef7_row3_col1" class="data row3 col1" >Australia</td>
#       <td id="T_3bef7_row3_col2" class="data row3 col2" >Peanut Butter Cubes</td>
#       <td id="T_3bef7_row3_col3" class="data row3 col3" >27-Apr-22</td>
#       <td id="T_3bef7_row3_col4" class="data row3 col4" >$12,726 </td>
#       <td id="T_3bef7_row3_col5" class="data row3 col5" >342</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3bef7_row4_col0" class="data row4 col0" >Jehu Rudeforth</td>
#       <td id="T_3bef7_row4_col1" class="data row4 col1" >UK</td>
#       <td id="T_3bef7_row4_col2" class="data row4 col2" >Peanut Butter Cubes</td>
#       <td id="T_3bef7_row4_col3" class="data row4 col3" >24-Feb-22</td>
#       <td id="T_3bef7_row4_col4" class="data row4 col4" >$13,685 </td>
#       <td id="T_3bef7_row4_col5" class="data row4 col5" >184</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3bef7_row5_col0" class="data row5 col0" >Van Tuxwell</td>
#       <td id="T_3bef7_row5_col1" class="data row5 col1" >India</td>
#       <td id="T_3bef7_row5_col2" class="data row5 col2" >Smooth Sliky Salty</td>
#       <td id="T_3bef7_row5_col3" class="data row5 col3" >06-Jun-22</td>
#       <td id="T_3bef7_row5_col4" class="data row5 col4" >$5,376 </td>
#       <td id="T_3bef7_row5_col5" class="data row5 col5" >38</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3bef7_row6_col0" class="data row6 col0" >Oby Sorrel</td>
#       <td id="T_3bef7_row6_col1" class="data row6 col1" >UK</td>
#       <td id="T_3bef7_row6_col2" class="data row6 col2" >99% Dark & Pure</td>
#       <td id="T_3bef7_row6_col3" class="data row6 col3" >25-Jan-22</td>
#       <td id="T_3bef7_row6_col4" class="data row6 col4" >$13,685 </td>
#       <td id="T_3bef7_row6_col5" class="data row6 col5" >176</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3bef7_row7_col0" class="data row7 col0" >Gunar Cockshoot</td>
#       <td id="T_3bef7_row7_col1" class="data row7 col1" >Australia</td>
#       <td id="T_3bef7_row7_col2" class="data row7 col2" >After Nines</td>
#       <td id="T_3bef7_row7_col3" class="data row7 col3" >24-Mar-22</td>
#       <td id="T_3bef7_row7_col4" class="data row7 col4" >$3,080 </td>
#       <td id="T_3bef7_row7_col5" class="data row7 col5" >73</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3bef7_row8_col0" class="data row8 col0" >Jehu Rudeforth</td>
#       <td id="T_3bef7_row8_col1" class="data row8 col1" >New Zealand</td>
#       <td id="T_3bef7_row8_col2" class="data row8 col2" >50% Dark Bites</td>
#       <td id="T_3bef7_row8_col3" class="data row8 col3" >20-Apr-22</td>
#       <td id="T_3bef7_row8_col4" class="data row8 col4" >$3,990 </td>
#       <td id="T_3bef7_row8_col5" class="data row8 col5" >59</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3bef7_row9_col0" class="data row9 col0" >Brien Boise</td>
#       <td id="T_3bef7_row9_col1" class="data row9 col1" >Australia</td>
#       <td id="T_3bef7_row9_col2" class="data row9 col2" >99% Dark & Pure</td>
#       <td id="T_3bef7_row9_col3" class="data row9 col3" >04-Jul-22</td>
#       <td id="T_3bef7_row9_col4" class="data row9 col4" >$2,835 </td>
#       <td id="T_3bef7_row9_col5" class="data row9 col5" >102</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3bef7_row10_col0" class="data row10 col0" >Rafaelita Blaksland</td>
#       <td id="T_3bef7_row10_col1" class="data row10 col1" >UK</td>
#       <td id="T_3bef7_row10_col2" class="data row10 col2" >Smooth Sliky Salty</td>
#       <td id="T_3bef7_row10_col3" class="data row10 col3" >13-Jan-22</td>
#       <td id="T_3bef7_row10_col4" class="data row10 col4" >$4,704 </td>
#       <td id="T_3bef7_row10_col5" class="data row10 col5" >62</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3bef7_row11_col0" class="data row11 col0" >Barr Faughny</td>
#       <td id="T_3bef7_row11_col1" class="data row11 col1" >USA</td>
#       <td id="T_3bef7_row11_col2" class="data row11 col2" >Orange Choco</td>
#       <td id="T_3bef7_row11_col3" class="data row11 col3" >10-Mar-22</td>
#       <td id="T_3bef7_row11_col4" class="data row11 col4" >$3,703 </td>
#       <td id="T_3bef7_row11_col5" class="data row11 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3bef7_row12_col0" class="data row12 col0" >Mallorie Waber</td>
#       <td id="T_3bef7_row12_col1" class="data row12 col1" >Canada</td>
#       <td id="T_3bef7_row12_col2" class="data row12 col2" >Eclairs</td>
#       <td id="T_3bef7_row12_col3" class="data row12 col3" >13-Jan-22</td>
#       <td id="T_3bef7_row12_col4" class="data row12 col4" >$1,442 </td>
#       <td id="T_3bef7_row12_col5" class="data row12 col5" >286</td>
#     </tr>
#     <tr>
#       <th id="T_3bef7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3bef7_row13_col0" class="data row13 col0" >Karlen McCaffrey</td>
#       <td id="T_3bef7_row13_col1" class="data row13 col1" >New Zealand</td>
#       <td id="T_3bef7_row13_col2" class="data row13 col2" >Drinking Coco</td>
#       <td id="T_3bef7_row13_col3" class="data row13 col3" >28-Jul-22</td>
#       <td id="T_3bef7_row13_col4" class="data row13 col4" >$168 </td>
#       <td id="T_3bef7_row13_col5" c

# %% [markdown]
# <h3>Descriptive Analyse
#  Parte koluna Amount</h3>

# %%
choco_clean[['Amount', 'Boxes Shipped']].describe()
# Out:
#        Boxes Shipped
# count      100.00000
# mean       160.96000
# std        124.42814
# min          6.00000
# 25%         68.75000
# 50%        138.50000
# 75%        241.00000
# max        581.00000

# %%
choco_clean['Sales Person'].value_counts()
# Out:
# Sales Person
# Van Tuxwell            9
# Andria Kimpton         8
# Roddy Speechley        8
# Karlen McCaffrey       8
# Marney O'Breen         6
# Jehu Rudeforth         5
# Dennison Crosswaite    5
# Brien Boise            5
# Camilla Castle         4
# Kelci Walkden          4
# Curtice Advani         4
# Beverie Moffet         4
# Husein Augar           3
# Wilone O'Kielt         3
# Oby Sorrel             3
# Gigi Bohling           3
# Madelene Upcott        3
# Mallorie Waber         2
# Barr Faughny           2
# Rafaelita Blaksland    2
# Kaine Padly            2
# Gunar Cockshoot        2
# Jan Morforth           2
# Dotty Strutley         2
# Ches Bonnell           1
# Name: count, dtype: int64

# %%
choco_clean['Country'].value_counts()
# Out:
# Country
# Australia      23
# USA            21
# Canada         15
# UK             14
# India          14
# New Zealand    13
# Name: count, dtype: int64

# %%
choco_clean['Product'].value_counts()
# Out:
# Product
# After Nines             8
# Organic Choco Syrup     8
# Peanut Butter Cubes     7
# 50% Dark Bites          7
# Eclairs                 7
# Spicy Special Slims     6
# 99% Dark & Pure         6
# Fruit & Nut Bars        6
# 85% Dark Bars           6
# Drinking Coco           5
# Almond Choco            5
# Manuka Honey Choco      4
# Raspberry Choco         4
# Orange Choco            4
# White Choc              3
# Smooth Sliky Salty      3
# Milk Bars               3
# Caramel Stuffed Bars    2
# Mint Chip Choco         2
# Choco Coated Almonds    2
# Baker's Choco Chips     1
# 70% Dark Bites          1
# Name: count, dtype: int64

# %%
# Pie chart Product
product_counts = choco_clean['Product'].value_counts()
plt.figure(figsize=(30,20))
plt.pie(product_counts, labels=product_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Produk Terjual')
plt.show()
